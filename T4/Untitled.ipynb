# %%
import pyopencl as cl
platforms = cl.get_platforms()
for p in platforms:
    print(p.name)
    #for e in p.extensions_with_version:
    #    print(e.name, e.version)
# Out:
# Intel(R) OpenCL Graphics
# [<pyopencl.Device 'Intel(R) Iris(R) Xe Graphics' on 'Intel(R) OpenCL Graphics' at 0x55f641ae1180>]
